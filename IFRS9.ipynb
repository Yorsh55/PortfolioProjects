# %% [markdown]
# # IFRS9 Portfolio Analytics Using Python and Atoti
#
#
# In this notebook I will provide a practical implementation to address daily credit portfolio monitoring needs, in particular to track and explain expected credit losses per IFRS 9 standard, perform vintage analysis, drill-down to loan-level data, analyze changes between periods and determine main drivers behind the portfolio risk KPIs.
#
#
#
# As a result of the Crisis of 2008, the accounting standards were redesigned, which culminated with the International Financial Reporting Standard number 9 (IFRS 9) and Current Expected Credit Loss (CECL). They key innovation of the new standard was the requirement to recognize in financial statements not only the incurred losses for a credit portfolio, but compute a forward looking measure - expected credit losses for a portfolio.
#
# By common practice, the expected credit losses computation relies on three ingredients:
#
# 1. **Probability of default (PD)**
# 2. **Loss given default (LGD)**
# 3. **Exposure at default (EAD)**
#
# Continue reading to learn how loan-level credit risk data can be consolidated in an analytical app - IFRS 9 app - powered by static attributes and analized interactively in the UI.
#
# Please note all the installation commands and instructions were performed on a MAC OS using Anaconda and Python.

# %%
#Install atoti jupyterlab extension

pip install atoti-jupyterlab
# Out:
# Requirement already satisfied: atoti-jupyterlab in ./opt/anaconda3/lib/python3.9/site-packages (0.6.5)
# Requirement already satisfied: atoti-core==0.6.5 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti-jupyterlab) (0.6.5)
# Requirement already satisfied: atoti==0.6.5 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti-jupyterlab) (0.6.5)
# Requirement already satisfied: atoti-query==0.6.5 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti-jupyterlab) (0.6.5)
# Requirement already satisfied: jupyterlab~=3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti-jupyterlab) (3.3.2)
# Requirement already satisfied: numpy~=1.22 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (1.22.3)
# Requirement already satisfied: pyarrow in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (6.0.1)
# Requirement already satisfied: typing-extensions in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (4.1.1)
# Requirement already satisfied: typeguard in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (2.13.3)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (1.4.2)
# Requirement already satisfied: jdk4py~=11.0 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (11.0.13.1)
# Requirement already satisfied: py4j~=0.10.9 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti==0.6.5->atoti-jupyterlab) (0.10.9.5)
# Requirement already satisfied: importlib-metadata~=4.10 in ./opt/anaconda3/lib/python3.9/site-packages (from atoti-core==0.6.5->atoti-jupyterlab) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in ./opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata~=4.10->atoti-core==0.6.5->atoti-jupyterlab) (3.7.0)
# Requirement already satisfied: ipython in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (8.2.0)
# Requirement already satisfied: packaging in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (21.3)
# Requirement already satisfied: jinja2>=2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (2.11.3)
# Requirement already satisfied: tornado>=6.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (6.1)
# Requirement already satisfied: jupyter-core in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (4.9.2)
# Requirement already satisfied: nbclassic~=0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (0.3.5)
# Requirement already satisfied: jupyter-server~=1.4 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (1.13.5)
# Requirement already satisfied: jupyterlab-server~=2.10 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab~=3.0->atoti-jupyterlab) (2.10.3)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.1->jupyterlab~=3.0->atoti-jupyterlab) (2.0.1)
# Requirement already satisfied: pyzmq>=17 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (22.3.0)
# Requirement already satisfied: argon2-cffi in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.13.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (3.5.0)
# Requirement already satisfied: prometheus-client in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.13.1)
# Requirement already satisfied: nbformat in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (5.3.0)
# Requirement already satisfied: Send2Trash in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (6.1.12)
# Requirement already satisfied: nbconvert in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (6.4.4)
# Requirement already satisfied: websocket-client in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.58.0)
# Requirement already satisfied: traitlets>=5 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (5.1.1)
# Requirement already satisfied: ipython-genutils in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.2.0)
# Requirement already satisfied: idna>=2.8 in ./opt/anaconda3/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (3.3)
# Requirement already satisfied: sniffio>=1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (2.8.2)
# Requirement already satisfied: json5 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (4.4.0)
# Requirement already satisfied: entrypoints>=0.2.2 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (0.4)
# Requirement already satisfied: babel in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (2.9.1)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (2.27.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (21.4.0)
# Requirement already satisfied: notebook<7 in ./opt/anaconda3/lib/python3.9/site-packages (from nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (6.4.8)
# Requirement already satisfied: nest-asyncio>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (1.5.5)
# Requirement already satisfied: ipykernel in ./opt/anaconda3/lib/python3.9/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (6.9.1)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (1.16.0)
# Requirement already satisfied: ptyprocess in ./opt/anaconda3/lib/python3.9/site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (1.15.0)
# Requirement already satisfied: pycparser in ./opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (2.21)
# Requirement already satisfied: pytz>=2015.7 in ./opt/anaconda3/lib/python3.9/site-packages (from babel->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (2021.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (0.1.2)
# Requirement already satisfied: appnope in ./opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.0->atoti-jupyterlab) (1.5.1)
# Requirement already satisfied: backcall in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (2.11.2)
# Requirement already satisfied: decorator in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (5.1.1)
# Requirement already satisfied: pickleshare in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (4.8.0)
# Requirement already satisfied: stack-data in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.8.3)
# Requirement already satisfied: wcwidth in ./opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.2.5)
# Requirement already satisfied: jupyterlab-pygments in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.1.2)
# Requirement already satisfied: testpath in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.8.4)
# Requirement already satisfied: bleach in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (4.11.1)
# Requirement already satisfied: defusedxml in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.7.1)
# Requirement already satisfied: fastjsonschema in ./opt/anaconda3/lib/python3.9/site-packages (from nbformat->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (2.15.1)
# Requirement already satisfied: soupsieve>1.2 in ./opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (2.3.1)
# Requirement already satisfied: webencodings in ./opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->atoti-jupyterlab) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from packaging->jupyterlab~=3.0->atoti-jupyterlab) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab~=3.0->atoti-jupyterlab) (2.0.4)
# Requirement already satisfied: pure-eval in ./opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.2.2)
# Requirement already satisfied: asttokens in ./opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyterlab~=3.0->atoti-jupyterlab) (2.0.5)
# Requirement already satisfied: executing in ./opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyterlab~=3.0->atoti-jupyterlab) (0.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import atoti and create a session

import atoti as tt

session = tt.Session(user_content_storage="content", java_options=["-Xmx8G"])
session.link()
# Out:
# Welcome to atoti 0.6.5!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.
# Open the notebook in JupyterLab with the atoti extension enabled to see this link.

# %% [markdown]
# # Input Data overview
#
# We will load the data used by the ECL calculation into in-memory datastores.
#
# The sample data will be fetched from csv files hosted on s3, and you can replace them with your own sources.
#
# The sample data set is based on the Lending Club dataset available on Kaggle and mocked-up the risk engine outputs - PDs, LGDs, EADs and stages - to illustrate how the IFRS 9 metrics can be computed and visualized in an analytical app.
#
# We'll use these three datastores:
#
# 1. risk_engine_data keeps information on individual loans, explosures, stages, credit risk parameters for ECL calculation and other attributes by date.
#
# 2. lending_club_data keeps additional data - loan attributes and amounts.
#
# 3. loans_at_inception is storing loan opening information, such as opening date and opening risk characteristics.

# %% [markdown]
# ## Credit Risk Engine Inputs

# %%
# !conda install -c conda-forge python-wget -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
from zipfile import ZipFile

import wget
from IPython.display import clear_output, display

# %%
def bar_custom(current, total, width=80):
    clear_output(wait=True)
    print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))


url = "https://s3.eu-west-3.amazonaws.com/data.atoti.io/notebooks/ifrs9/lending-club-data.zip"
filename = wget.download(url, bar=bar_custom)
# Out:
# Downloading: 100% [15300455 / 15300455] bytes

# %%
# unzipping the file
with ZipFile("lending-club-data.zip", "r") as zipObj:
    # Extract all the contents of zip file in current directory
    zipObj.extractall()

# %%
src = "./"

# %%
risk_engine_data = session.read_csv(
    src + "lending-club-data/risk-engine/*.csv",
    keys=["Reporting Date", "id"],
    table_name="Credit Risk",
    types={
        "EAD": tt.type.NULLABLE_DOUBLE,
        "Stage": tt.type.NULLABLE_INT,
        "Previous Stage": tt.type.NULLABLE_INT,
        "DaysPastDue": tt.type.NULLABLE_DOUBLE,
    },
)
risk_engine_data.head(3)
# Out:
#                           PD12      PDLT          EAD  LGD  Stage  \
# Reporting Date id
# 2007-08-01     83979  0.010321  0.012385  3115.824071  0.7      1
# 2007-09-01     83979  0.010798  0.012958  3218.853834  0.7      1
# 2007-06-01     83979  0.011905  0.014286  3000.000000  0.8      1
#
#                       Previous PD12  Previous PDLT  Previous EAD  \
# Reporting Date id
# 2007-08-01     83979       0.011905       0.014286   3000.000000
# 2007-09-01     83979       0.010321       0.012385   3115.824071
# 2007-06-01     83979       0.011905       0.014286   3000.000000
#
#                       Previous LGD  Previous Stage  DaysPastDue  \
# Reporting Date id
# 2007-08-01     83979           0.8               1          NaN
# 2007-09-01     83979           0.7               1          NaN
# 2007-06-01     83979           0.8               1          NaN
#
#                       Months Since Inception
# Reporting Date id
# 2007-08-01     83979                       2
# 2007-09-01     83979                       3
# 2007-06-01     83979                       0

# %% [markdown]
# ## Creating a Cube and Adding LendingClub data
#
# The LendingClub data can be downloaded from: Janio Martinez Bachmann on Kaggle.

# %%
cube = session.create_cube(risk_engine_data, "IFRS9")

# %%
lending_club_data = session.read_csv(
    src + "lending-club-data/loans.csv",
    keys=["id"],
    table_name="Lending Club Data",
    process_quotes=True,
)
risk_engine_data.join(lending_club_data)
lending_club_data.head(3)
# Out:
#           member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# id
# 57364554   61067280    10000.0      10000.0          10000.0  36 months
# 20760587   23033190    15225.0      15225.0          15225.0  60 months
# 7697788     9399474    23300.0      23300.0          23300.0  60 months
#
#           int_rate  installment grade sub_grade              emp_title  ...  \
# id                                                                      ...
# 57364554     12.69       335.45     C        C2               operator  ...
# 20760587     25.99       455.76     G        G4    Driving Team Member  ...
# 7697788      17.10       580.32     C        C5  accounting technician  ...
#
#          max_bal_bc all_util  total_rev_hi_lim inq_fi total_cu_tl  \
# id
# 57364554        NaN      NaN           21600.0    NaN         NaN
# 20760587        NaN      NaN            3300.0    NaN         NaN
# 7697788         NaN      NaN           36400.0    NaN         NaN
#
#          inq_last_12m Opening Year Opening Month Opening Day maturity_date
# id
# 57364554          NaN         2015             7           1    2018-07-01
# 20760587          NaN         2014             7           1    2019-07-01
# 7697788           NaN         2013            10           1    2018-10-01
#
# [3 rows x 77 columns]

# %% [markdown]
# ## Adding loans opening parameters

# %%
loans_at_inception = session.read_csv(
    "lending-club-data/static.csv",
    keys=["id"],
    table_name="Parameters at inception",
)
loans_at_inception.head(3)
# Out:
# ---------------------------------------------------------------------------
# AtotiJavaException                        Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 loans_at_inception = session.read_csv(
#       2     "lending-club-data/static.csv",
#       3     keys=["id"],
#       4     table_name="Parameters at inception",
#       5 )
#       6 loans_at_inception.head(3)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_telemetry.py:225, in _track_calls.<locals>.function_wrapper(*args, **kwargs)
#     222 call_tracker.tracking = True
#     224 try:
# --> 225     return _track_call(function, call_path, *args, **kwargs)
#     226 finally:
#     227     call_tracker.tracking = False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_telemetry.py:188, in _track_call(function, call_path, *args, **kwargs)
#     185     except:  # pylint: disable=bare-except
#     186         # Do nothing to let the previous error be the one presented to the user.
#     187         ...
# --> 188     raise error
#     189 finally:
#     190     arguments: Dict[str, str] = {}
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_telemetry.py:181, in _track_call(function, call_path, *args, **kwargs)
#     179 call_time = time.perf_counter()
#     180 try:
# --> 181     return function(*args, **kwargs)
#     182 except Exception as error:  # pylint: disable=broad-except
#     183     try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_runtime_type_checking_utils.py:179, in _TypecheckWrapperFactory.create_wrapper.<locals>.typechecked_func_wrapper(*args, **kwargs)
#     176 typeguard.check_argument_types(memo)
#     178 # Call the actual function.
# --> 179 return self._func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti_core/doc.py:21, in doc.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(function)
#      20 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> Any:
# ---> 21     return function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/session.py:507, in Session.read_csv(self, path, keys, table_name, separator, encoding, process_quotes, partitioning, types, columns, array_separator, hierarchized_columns, date_patterns, client_side_encryption)
#     500 separator = separator if separator is not None else csv_file_format.separator
#     501 date_patterns = (
#     502     {**csv_file_format.date_patterns, **date_patterns}
#     503     if date_patterns is not None
#     504     else csv_file_format.date_patterns
#     505 )
# --> 507 table = self.create_table(
#     508     table_name,
#     509     types=types,
#     510     keys=keys,
#     511     partitioning=partitioning,
#     512     hierarchized_columns=hierarchized_columns,
#     513 )
#     514 table.load_csv(
#     515     full_path,
#     516     columns=columns,
#    (...)
#     522     client_side_encryption=client_side_encryption,
#     523 )
#     524 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_telemetry.py:220, in _track_calls.<locals>.function_wrapper(*args, **kwargs)
#     214 @functools.wraps(function)
#     215 def function_wrapper(
#     216     *args: _P.args,
#     217     **kwargs: _P.kwargs,
#     218 ) -> _R:
#     219     if call_tracker.tracking:
# --> 220         return function(*args, **kwargs)
#     222     call_tracker.tracking = True
#     224     try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_runtime_type_checking_utils.py:179, in _TypecheckWrapperFactory.create_wrapper.<locals>.typechecked_func_wrapper(*args, **kwargs)
#     176 typeguard.check_argument_types(memo)
#     178 # Call the actual function.
# --> 179 return self._func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti_core/doc.py:21, in doc.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(function)
#      20 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> Any:
# ---> 21     return function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/session.py:314, in Session.create_table(self, name, types, keys, partitioning, hierarchized_columns, **kwargs)
#     284 """Create a table from a schema.
#     285
#     286 Args:
#    (...)
#     311
#     312 """
#     313 private_parameters = _CreateTablePrivateParameters(**kwargs)
# --> 314 self._java_api.create_table(
#     315     name,
#     316     types=types,
#     317     keys=keys,
#     318     partitioning=partitioning,
#     319     hierarchized_columns=hierarchized_columns,
#     320     is_parameter_table=private_parameters.is_parameter_table,
#     321 )
#     322 return Table(_name=name, _java_api=self._java_api)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/atoti/_java_api.py:135, in _enhance_py4j_errors.<locals>.wrapped_method(self, *args, **kwargs)
#     129 except Py4JJavaError as java_exception:
#     130     cause = (
#     131         str(java_exception)
#     132         if get_env_flag(_ATOTI_VERBOSE_JAVA_EXCEPTIONS)
#     133         else self.get_throwable_root_cause(java_exception.java_exception)
#     134     )
# --> 135     raise AtotiJavaException(
#     136         cause,
#     137         java_traceback=str(java_exception),
#     138         java_exception=java_exception,
#     139     ) from None
#
# AtotiJavaException: A store with the name Parameters at inception already exists!
# If you want to recreate this store,you will have to re-create the session.

# %%
# Linking contracts and their opening information
risk_engine_data.join(loans_at_inception)

# %% [markdown]
# ## Cube schema
# Based on the data we've loaded and linked together, this is the view of our current cube schema.

# %%
cube.schema

# %% [markdown]
# # Getting started with cube configuration
#
# In this section I'm showing some actions that you can apply to your newly created cube.

# %%
# These are the variables for faster access to the cube data elements:
l, m, h = cube.levels, cube.measures, cube.hierarchies

# %%
# By setting the sort on the reporting date to DESC, we make sure that the latest date appears by default.
l["Reporting Date"].order = tt.NaturalOrder(ascending=False)

# %%
# Multi-level hierarchies come handy when you have a typical way to expand data:
h["Opening Date (detailed)"] = {
    "Year": lending_club_data["Opening Year"],
    "Month": lending_club_data["Opening Month"],
    "Day": lending_club_data["Opening Day"],
}

# %%
# with 0.6.0, int and long table columns, unless they are key columns, automatically become measures instead of levels.
# With this change, all the numeric columns behave the same.

h["Stage"] = [risk_engine_data["Stage"]]
h["Months Since Inception"] = [risk_engine_data["Months Since Inception"]]

# %% [markdown]
# # Measures visualizing credit risk inputs
# In this section you will find various measures that we create to visualize risk engine output in the UI.
#
# Stages and their variations.
#
# In this section, we define measures to visualize Stages and their variations.
#
# As a reminder, Impairment of financial assets is recognised in stages:
#
# 1. **Stage 1** Low credit risk or no increase since initial recognition: one-year ECL.
# 2. **Stage 2** If the credit risk increases significantly and is not considered low: lifetime ECL.
# 3. **Stage 3** Impaired assets.

# %%
m["Stage"] = tt.value(risk_engine_data["Stage"])
m["Stage"].folder = "Stage"

# This is how we can create measures to display the previous value and daily changes side by side with the value:
m["Previous Stage"] = tt.shift(m["Stage"], on=l["Reporting Date"], offset=1)
m["Previous Stage"].folder = "Stage"

m["Stage Variation"] = tt.where(
    m["Previous Stage"] != None, m["Stage"] - m["Previous Stage"]
)
m["Stage Variation"].folder = "Stage"
m["Stage Variation"].formatter = "DOUBLE[+#,###;-#,###]"

# %% [markdown]
# # EAD Aggregation
# The Exposure At Default is the estimated amount of loss a bank may be exposed to when a debtor defaults on a loan.

# %%
m["EAD"] = tt.agg.sum(risk_engine_data["EAD"])
m["EAD"].folder = "EAD"

# This is how we can create measures to display the previous value and daily changes side by side with the value:
m["Previous EAD"] = tt.shift(m["EAD"], on=l["Reporting Date"], offset=1)
m["Previous EAD"].folder = "EAD"

m["EAD (Chg)"] = tt.where(m["Previous EAD"] != None, m["EAD"] - m["Previous EAD"])
m["EAD (Chg)"].folder = "EAD"
m["EAD (Chg)"].formatter = "DOUBLE[+#,###.##;-#,###.##]"

m["EAD (Chg %)"] = tt.where(m["Previous EAD"] != 0, m["EAD (Chg)"] / m["Previous EAD"])
m["EAD (Chg %)"].folder = "EAD"
m["EAD (Chg %)"].formatter = "DOUBLE[+#,###.##%;-#,###.##%]"

# %%
#Query for the EAD and variations

cube.query(
    m["EAD"],
    m["Previous EAD"],
    m["EAD (Chg)"],
    m["EAD (Chg %)"],
    levels=[l["Reporting Date"]],
)
# Out:
#                            EAD    Previous EAD       EAD (Chg) EAD (Chg %)
# Reporting Date
# 2015-12-01      221,161,692.74  195,087,608.42  +26,074,084.31     +13.37%
# 2015-11-01      195,087,608.42  193,230,610.50   +1,856,997.92      +0.96%
# 2015-10-01      193,230,610.50  178,855,504.93  +14,375,105.57      +8.04%
# 2015-09-01      178,855,504.93  175,931,125.20   +2,924,379.73      +1.66%
# 2015-08-01      175,931,125.20  175,642,632.00      +288,493.2      +0.16%
# ...                        ...             ...             ...         ...
# 2007-11-01          111,331.82       84,033.52       +27,298.3     +32.49%
# 2007-10-01           84,033.52       70,346.58      +13,686.94     +19.46%
# 2007-09-01           70,346.58       55,365.82      +14,980.76     +27.06%
# 2007-08-01           55,365.82        3,000.00      +52,365.82  +1,745.53%
# 2007-06-01            3,000.00
#
# [99 rows x 4 columns]

# %% [markdown]
# # Visualizing PD
# The Probability Of Default is the likelihood that your debtor will default on its debts (goes bankrupt or so) within certain period (12 months for loans in Stage 1 and life-time for other loans).
#
# - PD (12) - is 12 month probability of default.
# - PD (LT) - is the lifetime probability of default.

# %% [markdown]
# ## 12 months PD and variations

# %%
m["PD (12)"] = tt.agg.mean(risk_engine_data["PD12"])
m["PD (12)"].folder = "PD"
m["PD (12)"].formatter = "DOUBLE[#,###.##%]"

m["Previous PD (12)"] = tt.shift(m["PD (12)"], on=l["Reporting Date"], offset=1)
m["Previous PD (12)"].folder = "PD"
m["Previous PD (12)"].formatter = "DOUBLE[#,###.##%]"

m["PD (12) (Chg)"] = tt.where(
    m["Previous PD (12)"] != None, m["PD (12)"] - m["Previous PD (12)"]
)
m["PD (12) (Chg)"].folder = "PD"
m["PD (12) (Chg)"].formatter = "DOUBLE[+#,###.##%;-#,###.##%]"

# %% [markdown]
# ## Lifetime PD and variations

# %%
m["PD (LT)"] = tt.agg.mean(risk_engine_data["PDLT"])
m["PD (LT)"].folder = "PD"
m["PD (LT)"].formatter = "DOUBLE[#,###.##%]"

m["Opening PD (LT)"] = tt.agg.mean(loans_at_inception["Opening PDLT"])
m["Opening PD (LT)"].folder = "PD"

m["Previous PD (LT)"] = tt.shift(m["PD (LT)"], on=l["Reporting Date"], offset=1)
m["Previous PD (LT)"].folder = "PD"

m["PD (LT) (Chg)"] = tt.where(
    m["Previous PD (LT)"] != None, m["PD (LT)"] - m["Previous PD (LT)"]
)
m["PD (LT) (Chg)"].folder = "PD"

# Variation from opening
m["PD (LT) Variation"] = (m["PD (LT)"] - m["Opening PD (LT)"]) / m["Opening PD (LT)"]
m["PD (LT) Variation"].folder = "PD"
m["PD (LT) Variation"].formatter = "DOUBLE[+#,###.##%;-#,###.##%]"

# %% [markdown]
# # Visualizing LGD
# The Lost Given Default is the percentage that you can lose when the debtor defaults.

# %%
m["LGD"] = tt.agg.mean(risk_engine_data["LGD"])
m["LGD"].folder = "LGD"
m["LGD"].formatter = "DOUBLE[#,###.##%]"

m["Previous LGD"] = tt.shift(m["LGD"], on=l["Reporting Date"], offset=1)
m["Previous LGD"].folder = "LGD"
m["Previous LGD"].formatter = "DOUBLE[#,###.##%]"

# %% [markdown]
# ## Summary
#
# We have created measures for credit risk inputs - EAD, PD, LGD, stages and their variations.
#
# Other measures that might be useful for visualization include - curing time, time weighted by EAD, statistics on the number of days past due and other.

# %% [markdown]
# # ECL computation
# The Expected Credit Loss is a probability-weighted estimate of credit loss. Depending on the "Stage" of a loan, the ECL is computed per one of the following formulae:
#
#
#
# - **IFRS Stage 1**: $ECL$ $=$ $EAD$ $⋅$ $PD$ $12M$ $⋅$ $LGD$
#
# - **IFRS Stage 2**: $ECL$ $=$ $EAD$ $⋅$ $PD$ $LT$ $⋅$ $LGD$
#
# - **IFRS Stage 3**: $ECL$ $=$ $EAD$ $⋅$ $LGD$
#
# Let's define each of these expressions:

# %%
ecl_stage_1 = tt.agg.sum_product(
    risk_engine_data["LGD"], risk_engine_data["EAD"], risk_engine_data["PD12"]
)
ecl_stage_2 = tt.agg.sum_product(
    risk_engine_data["LGD"], risk_engine_data["EAD"], risk_engine_data["PDLT"]
)
ecl_stage_3 = tt.agg.sum_product(risk_engine_data["LGD"], risk_engine_data["EAD"])

# %%
#The measure visible in the UI will pick the correct formula depending on the stage:

m["ECL"] = (
    tt.filter(ecl_stage_1, l["Stage"] == 1)
    + tt.filter(ecl_stage_2, l["Stage"] == 2)
    + tt.filter(ecl_stage_3, l["Stage"] == 3)
)
m["ECL"].folder = "ECL"

# %%
cube.query(m["ECL"], levels=[l["Reporting Date"]])
# Out:
#                           ECL
# Reporting Date
# 2015-12-01      19,587,038.55
# 2015-11-01      17,442,089.30
# 2015-10-01      15,158,955.74
# 2015-09-01      18,832,579.74
# 2015-08-01      18,470,468.21
# ...                       ...
# 2007-11-01          13,004.20
# 2007-10-01          12,634.27
# 2007-09-01          10,692.22
# 2007-08-01           6,162.80
# 2007-06-01              28.57
#
# [99 rows x 1 columns]

# %%
#Let's create measures to visualize the previous reporting date values and changes:

m["Previous ECL"] = tt.shift(m["ECL"], on=l["Reporting Date"], offset=1)
m["Previous ECL"].folder = "ECL"

m["ECL (Chg)"] = tt.where(m["Previous ECL"] != None, m["ECL"] - m["Previous ECL"])
m["ECL (Chg)"].folder = "ECL"

m["ECL (Chg %)"] = tt.where(m["Previous ECL"] != 0, m["ECL (Chg)"] / m["Previous ECL"])
m["ECL (Chg %)"].folder = "ECL"
m["ECL (Chg %)"].formatter = "DOUBLE[+#,###.##%;-#,###.##%]"

m["ECL of old contracts"] = tt.where(l["Reporting Date"] != l["issue_d"], m["ECL"])
m["ECL of old contracts"].folder = "ECL"

m["ECL (Chg without new contracts)"] = tt.where(
    m["Previous ECL"] != None, m["ECL of old contracts"] - m["Previous ECL"]
)
m["ECL (Chg without new contracts)"].folder = "ECL"

m["ECL (Chg % without new contracts)"] = tt.where(
    m["Previous ECL"] != 0, m["ECL (Chg without new contracts)"] / m["Previous ECL"]
)
m["ECL (Chg % without new contracts)"].folder = "ECL"
m["ECL (Chg % without new contracts)"].formatter = "DOUBLE[+#,###.##%;-#,###.##%]"

# %% [markdown]
# Now the ECL measures are computed from the EAD, PD and LGD every time a user displays ECL. This allows to manipulate the inputs.

# %% [markdown]
# # ECL Change Explainers
# Refers to measures attributing the change in ECL to the underlying factors - PD, LGD and EAD. To compute them, we will apply the same formula as for the ECL measure, but will keep each of the three factors at the level of the previous reporting date, so it has no effect on the ECL variation.

# %% [markdown]
# ## ECL variation due to PD changes

# %%
ecl_pd_explain_stage_1 = tt.agg.sum_product(
    risk_engine_data["LGD"],
    risk_engine_data["EAD"],
    risk_engine_data["Previous PD12"],
)
ecl_pd_explain_stage_2 = tt.agg.sum_product(
    risk_engine_data["LGD"],
    risk_engine_data["EAD"],
    risk_engine_data["Previous PDLT"],
)

m["ECL with previous PD"] = (
    tt.filter(ecl_pd_explain_stage_1, l["Stage"] == 1)
    + tt.filter(ecl_pd_explain_stage_2, l["Stage"] == 2)
    + tt.filter(ecl_stage_3, l["Stage"] == 3)
)

m["ECL variation due to PD changes"] = m["ECL"] - m["ECL with previous PD"]
m["ECL variation due to PD changes"].folder = "ECL"

# %%
cube.query(
    m["ECL (Chg)"],
    m["ECL variation due to PD changes"],
    levels=[l["Reporting Date"]],
)
# Out:
#                     ECL (Chg) ECL variation due to PD changes
# Reporting Date
# 2015-12-01       2,144,949.25                      -74,836.57
# 2015-11-01       2,283,133.56                     -114,668.10
# 2015-10-01      -3,673,624.00                      -52,715.77
# 2015-09-01         362,111.53                       11,310.57
# 2015-08-01          54,460.78                      -68,044.63
# ...                       ...                             ...
# 2007-11-01             369.93                         -217.57
# 2007-10-01           1,942.05                       -1,639.20
# 2007-09-01           4,529.42                          609.98
# 2007-08-01           6,134.22                           -3.45
# 2007-06-01                                                .00
#
# [99 rows x 2 columns]

# %% [markdown]
# ## ECL variation due to LGD changes

# %%
ecl_lgd_explain_stage_1 = tt.agg.sum_product(
    risk_engine_data["Previous LGD"],
    risk_engine_data["EAD"],
    risk_engine_data["PD12"],
)
ecl_lgd_explain_stage_2 = tt.agg.sum_product(
    risk_engine_data["Previous LGD"],
    risk_engine_data["EAD"],
    risk_engine_data["PDLT"],
)
ecl_lgd_explain_stage_3 = tt.agg.sum_product(
    risk_engine_data["Previous LGD"], risk_engine_data["EAD"]
)

m["ECL with previous LGD"] = (
    tt.filter(ecl_lgd_explain_stage_1, l["Stage"] == 1)
    + tt.filter(ecl_lgd_explain_stage_2, l["Stage"] == 2)
    + tt.filter(ecl_lgd_explain_stage_3, l["Stage"] == 3)
)

m["ECL variation due to LGD changes"] = m["ECL"] - m["ECL with previous LGD"]
m["ECL variation due to LGD changes"].folder = "ECL"

# %%
m["ecl_lgd_explain_stage_1"] = ecl_lgd_explain_stage_1

# %%
cube.query(
    m["ECL (Chg)"],
    m["ECL variation due to PD changes"],
    m["ECL variation due to LGD changes"],
    levels=[l["Reporting Date"]],
)
# Out:
#                     ECL (Chg) ECL variation due to PD changes  \
# Reporting Date
# 2015-12-01       2,144,949.25                      -74,836.57
# 2015-11-01       2,283,133.56                     -114,668.10
# 2015-10-01      -3,673,624.00                      -52,715.77
# 2015-09-01         362,111.53                       11,310.57
# 2015-08-01          54,460.78                      -68,044.63
# ...                       ...                             ...
# 2007-11-01             369.93                         -217.57
# 2007-10-01           1,942.05                       -1,639.20
# 2007-09-01           4,529.42                          609.98
# 2007-08-01           6,134.22                           -3.45
# 2007-06-01                                                .00
#
#                ECL variation due to LGD changes
# Reporting Date
# 2015-12-01                           -92,187.05
# 2015-11-01                         2,166,434.73
# 2015-10-01                        -4,975,314.63
# 2015-09-01                             8,330.88
# 2015-08-01                           219,780.45
# ...                                         ...
# 2007-11-01                            -2,101.52
# 2007-10-01                              -409.68
# 2007-09-01                              -879.90
# 2007-08-01                                -3.22
# 2007-06-01                                  .00
#
# [99 rows x 3 columns]

# %%
session.link()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to see this link.

# %% [markdown]
# ## ECL variation due to EAD changes

# %%
ecl_ead_explain_stage_1 = tt.agg.sum_product(
    risk_engine_data["LGD"],
    risk_engine_data["Previous EAD"],
    risk_engine_data["PD12"],
)
ecl_ead_explain_stage_2 = tt.agg.sum_product(
    risk_engine_data["LGD"],
    risk_engine_data["Previous EAD"],
    risk_engine_data["PDLT"],
)
ecl_ead_explain_stage_3 = tt.agg.sum_product(
    risk_engine_data["LGD"], risk_engine_data["Previous EAD"]
)

m["ECL with previous EAD"] = (
    tt.filter(ecl_ead_explain_stage_1, l["Stage"] == 1)
    + tt.filter(ecl_ead_explain_stage_2, l["Stage"] == 2)
    + tt.filter(ecl_ead_explain_stage_3, l["Stage"] == 3)
)

m["ECL variation due to EAD changes"] = m["ECL"] - m["ECL with previous EAD"]
m["ECL variation due to EAD changes"].folder = "ECL"

# %%
cube.query(
    m["ECL (Chg)"],
    m["ECL variation due to PD changes"],
    m["ECL variation due to LGD changes"],
    m["ECL variation due to EAD changes"],
    levels=[l["Reporting Date"]],
)
# Out:
#                     ECL (Chg) ECL variation due to PD changes  \
# Reporting Date
# 2015-12-01       2,144,949.25                      -74,836.57
# 2015-11-01       2,283,133.56                     -114,668.10
# 2015-10-01      -3,673,624.00                      -52,715.77
# 2015-09-01         362,111.53                       11,310.57
# 2015-08-01          54,460.78                      -68,044.63
# ...                       ...                             ...
# 2007-11-01             369.93                         -217.57
# 2007-10-01           1,942.05                       -1,639.20
# 2007-09-01           4,529.42                          609.98
# 2007-08-01           6,134.22                           -3.45
# 2007-06-01                                                .00
#
#                ECL variation due to LGD changes  \
# Reporting Date
# 2015-12-01                           -92,187.05
# 2015-11-01                         2,166,434.73
# 2015-10-01                        -4,975,314.63
# 2015-09-01                             8,330.88
# 2015-08-01                           219,780.45
# ...                                         ...
# 2007-11-01                            -2,101.52
# 2007-10-01                              -409.68
# 2007-09-01                              -879.90
# 2007-08-01                                -3.22
# 2007-06-01                                  .00
#
#                ECL variation due to EAD changes
# Reporting Date
# 2015-12-01                         1,403,871.63
# 2015-11-01                          -611,768.27
# 2015-10-01                           187,576.28
# 2015-09-01                          -449,413.47
# 2015-08-01                          -884,183.86
# ...                                         ...
# 2007-11-01                                96.86
# 2007-10-01                               204.50
# 2007-09-01                               197.93
# 2007-08-01                                  .84
# 2007-06-01                                  .00
#
# [99 rows x 4 columns]

# %% [markdown]
# # Unexplained variation
# You can notice that the unexplained ECL is quite huge - because our approach doesn't account for trade transitions.

# %%
m["ECL unexplained variation"] = (
    m["ECL (Chg)"]
    - m["ECL variation due to PD changes"]
    - m["ECL variation due to LGD changes"]
    - m["ECL variation due to EAD changes"]
)

# %%
cube.query(
    m["ECL (Chg)"],
    m["ECL variation due to PD changes"],
    m["ECL variation due to LGD changes"],
    m["ECL variation due to EAD changes"],
    m["ECL unexplained variation"],
    levels=[l["Reporting Date"]],
)
# Out:
#                     ECL (Chg) ECL variation due to PD changes  \
# Reporting Date
# 2015-12-01       2,144,949.25                      -74,836.57
# 2015-11-01       2,283,133.56                     -114,668.10
# 2015-10-01      -3,673,624.00                      -52,715.77
# 2015-09-01         362,111.53                       11,310.57
# 2015-08-01          54,460.78                      -68,044.63
# ...                       ...                             ...
# 2007-11-01             369.93                         -217.57
# 2007-10-01           1,942.05                       -1,639.20
# 2007-09-01           4,529.42                          609.98
# 2007-08-01           6,134.22                           -3.45
# 2007-06-01                                                .00
#
#                ECL variation due to LGD changes  \
# Reporting Date
# 2015-12-01                           -92,187.05
# 2015-11-01                         2,166,434.73
# 2015-10-01                        -4,975,314.63
# 2015-09-01                             8,330.88
# 2015-08-01                           219,780.45
# ...                                         ...
# 2007-11-01                            -2,101.52
# 2007-10-01                              -409.68
# 2007-09-01                              -879.90
# 2007-08-01                                -3.22
# 2007-06-01                                  .00
#
#                ECL variation due to EAD changes ECL unexplained variation
# Reporting Date
# 2015-12-01                         1,403,871.63                908,101.24
# 2015-11-01                          -611,768.27                843,135.20
# 2015-10-01                           187,576.28              1,166,830.11
# 2015-09-01                          -449,413.47                791,883.54
# 2015-08-01                          -884,183.86                786,908.82
# ...                                         ...                       ...
# 2007-11-01                                96.86                  2,592.16
# 2007-10-01                               204.50                  3,786.43
# 2007-09-01                               197.93                  4,601.41
# 2007-08-01                                  .84                  6,140.06
# 2007-06-01                                  .00                      -.00
#
# [99 rows x 5 columns]

# %% [markdown]
# # Vintage analysis
# In vintage analysis, the portfolio is broken down into “vintages” based on the origination month. This is because credit portfolios follow a certain lifecycle pattern with more loans defaulting in the first months of inception and stabilizing after a certain period.
#
# The Vintage analysis is simple in our IFRS 9 app:
#
# To break the portfolio into vintages, we will use "Opening date" hierarchy and put it on the rows if a pivot table
# then to observe the evolution of portfolio through time - we will put the "Reporting Date" hierarchy onto the columns of a pivot table.
# Then inside the pivot table, we can display any measure you want, for example, ECL, EAD, % of customers past due, % of loans past due.
#
# Let's take an example of the % of loans past due and create a special measure to visualize it.
#
# Total number of loans is available in the native cube measure "contributors.COUNT":

# %%
cube.query(m["contributors.COUNT"], levels=[l["Reporting Date"]]).head(5)
# Out:
#                 contributors.COUNT
# Reporting Date
# 2015-12-01                   13786
# 2015-11-01                   13141
# 2015-10-01                   12590
# 2015-09-01                   11842
# 2015-08-01                   11416

# %% [markdown]
# The number of contracts having more than 30 days past due:
#
# Below I'm creating various possibilities for the days past due threshold parameter. I will be able to choose them from a hierarchy:

# %%
PastDueDaysThresholds = cube.create_parameter_simulation(
    "PastDueDaysThresholds",
    measures={"PastDueDaysThreshold": 30.0},
    base_scenario_name=">30 days",
)

# %%
PastDueDaysThresholds += (">60 days", 60.0)
PastDueDaysThresholds += (">90 days", 90.0)

# %%
# Indicator - let's assume that a loan is classified as a past due due after 30 days of being "past due".
m["DaysPastDue"] = tt.value(risk_engine_data["DaysPastDue"])

# Number of contracts past due:
m["Num_Contracts_Past_due"] = tt.agg.sum(
    tt.where(m["DaysPastDue"] > m["PastDueDaysThreshold"], 1.0, 0.0),
    scope=tt.scope.origin(l["id"]),
)

m["% past due"] = m["Num_Contracts_Past_due"] / m["contributors.COUNT"]
m["% past due"].formatter = "DOUBLE[#,###.##%]"

# %%
cube.query(m["% past due"], levels=[l["Reporting Date"]])
# Out:
#                % past due
# Reporting Date
# 2015-12-01          3.87%
# 2015-11-01             4%
# 2015-10-01          4.04%
# 2015-09-01          4.18%
# 2015-08-01          4.21%
# ...                   ...
# 2007-11-01             0%
# 2007-10-01             0%
# 2007-09-01             0%
# 2007-08-01             0%
# 2007-06-01             0%
#
# [99 rows x 1 columns]

# %% [markdown]
# # Annex I: LendingClub data viz
#
# In this section we will create measures visualizing the LendingClub data. I'm creating a second cube to aggregate lending_club_data - so that there's no linkage with "reporting dates" and no duplication of data.
#
# Please note, that I'm operating with a subset of data - to save up time on loading data from s3.

# %%
cube2 = session.create_cube(lending_club_data, "Lending Club EDA")

# %%
m2 = cube2.measures

# %% [markdown]
# # Loan Amount

# %%
# The listed amount of the loan applied for by the borrower.
m2["loan_amount"] = tt.agg.sum(lending_club_data["loan_amnt"])
m2["loan_amount"].folder = "LendingClub"
# Average loan amount:
m2["loan_amount.MEAN"] = tt.agg.mean(lending_club_data["loan_amnt"])
m2["loan_amount.MEAN"].folder = "LendingClub"

# %%
session.visualize("Total loan amount")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize("Average loan size by Credit Score")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# # Interest rate
